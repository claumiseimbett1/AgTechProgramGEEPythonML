# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Datos ficticios
X = np.array([[1], [2], [3], [4], [5]])   # variable independiente
y = np.array([1, 2, 1.3, 3.75, 2.5])      # variable dependiente

# Crear y entrenar el modelo
modelo = LinearRegression()
modelo.fit(X, y)

# Predicciones
y_pred = modelo.predict(X)

# Métricas
mae = mean_absolute_error(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))
r2 = r2_score(y, y_pred)

# Mostrar resultados
print("Pendiente (coeficiente):", modelo.coef_[0])
print("Intercepto:", modelo.intercept_)
print("MAE:", mae)
print("RMSE:", rmse)
print("R²:", r2)

# Graficar
plt.scatter(X, y, color="blue", label="Datos reales")
plt.plot(X, y_pred, color="red", label="Recta ajustada")
plt.legend()
plt.show()
# Out:
# Pendiente (coeficiente): 0.47500000000000003
# Intercepto: 0.6850000000000003
# MAE: 0.6120000000000001
# RMSE: 0.7050886469090252
# R²: 0.47580134964150145
